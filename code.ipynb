# %%
# import random
# import time
# import numpy as np
# import matplotlib.pyplot as plt
# from inputimeout import inputimeout, TimeoutOccurred
# import pandas as pd
# import os
from functions import free_recall, save_data,serial_recall

# %% [markdown]
# ### #1: Run tests, n = number of consecutive tests EXPAND TERMINAL AFTER RUNNING

# %%
waits, corrects, inputs = serial_recall(n=3, length=10, wait = 1, chunking=False)
# Out:
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 1
# D
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 2
# X
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 3
# J
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 4
# I
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 5
# X
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 6
# R
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 7
# T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 8
# N
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# You should now enter the sequence:

# %%
waits, corrects, inputs = free_recall(n=2, length=20,wait=1, workingMemory=False, pause=0)
# Out:
# LOOK HERE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[220], line 1
# ----> 1 waits, corrects, inputs = free_recall(n=1, length=20,wait=1, workingMemory=True, pause=15)
#
# File c:\Users\CvcCl\OneDrive\Skrivebord\Kognition\02464---Mini-Project-1\functions.py:124, in free_recall(length, wait, n, workingMemory, pause)
#     122 print("LOOK HERE")
#     123 print("\n" * 10)
# --> 124 time.sleep(5)
#     125 for trial in range(n):
#     126     print("\n" * 40)
#
# KeyboardInterrupt:

# %%
waits, corrects, inputs
# Out:
# (array([1]),
#  array([['D', 'X', 'J', 'I', 'X', 'R', 'T', 'N']], dtype='<U1'),
#  array([['D', 'X', 'J', 'I', 'X', 'R', 'H', 'N']], dtype='<U1'))

# %% [markdown]
# ### #3: Choose file name: [DITNAVN]/eksperiment[EKSPERIMENTETSNUMMER].csv

# %%
data_file_name = "serial_recall_data.csv"
data_file_name = "Ali/eksperiment3.csv"

# %% [markdown]
# ### #4: Save data in csv file CHECK DATA BEFORE RUNNING

# %%
save_data(waits = waits, corrects=corrects,userInputs = inputs,data_file_name_input = data_file_name)
