# %%
import random
import time
import numpy as np
import matplotlib.pyplot as plt
from inputimeout import inputimeout, TimeoutOccurred
import pandas as pd
import os
from functions import free_recall, save_data, serial_recall

# %% [markdown]
# ### n = number of consecutive tests EXPAND TERMINAL AFTER RUNNING

# %%
waits, corrects, userInputs = serial_recall(length=8, wait=1, chunking = False)
# Out:
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 1
# S
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 2
# A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 3
# G
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 4
# X
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 5
# O
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 6
# L
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 7
# A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 8
# N
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# You should now enter the sequence:

# %%
waits, corrects, userInputs = free_recall(length=20, wait=1, workingMemory=False, pause=15)
# Out:
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  0
# 27
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  1
# 44
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  2
# 71
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  3
# 34
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  4
# 50
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  5
# 87
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  6
# 21
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  7
# 89
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  8
# 76
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  9
# 61
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  10
# 85
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  11
# 12
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# ### check output matrices

# %%
waits, corrects, userInputs
# Out:
# (array([1]),
#  array([['27', '44', '71', '34', '50', '87', '21', '89', '76', '61', '85',
#          '12', '49', '45', '70', '16', '53', '95', '54', '24']],
#        dtype='<U2'),
#  array([['16', '55', '95', '64', '24', '61', '40', '50', '36']],
#        dtype=object))

# %% [markdown]
# ### Save data in csv file CHECK DATA BEFORE RUNNING

# %%
data_file_name = "Kasper/eksperiment2_WorkingMemoryFalse.csv"

# %%
save_data(waits, corrects, userInputs, data_file_name_input = data_file_name)
