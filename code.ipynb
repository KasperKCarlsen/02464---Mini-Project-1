# %%
# import random
# import time
# import numpy as np
# import matplotlib.pyplot as plt
# from inputimeout import inputimeout, TimeoutOccurred
# import pandas as pd
# import os
from functions import free_recall, save_data,serial_recall

# %% [markdown]
# ### #1: Run tests, n = number of consecutive tests EXPAND TERMINAL AFTER RUNNING

# %%
waits, corrects, inputs = serial_recall(n=3, length=10, wait = 1, chunking=False)
# Out:
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 1
# T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 2
# L
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 3
# A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 4
# S
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 5
# Y
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 6
# J
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 7
# E
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 8
# R
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idx #: 9
# J
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
waits, corrects, inputs = free_recall(n=2, length=20,wait=2.5, workingMemory=False, pause=0)
# Out:
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LOOK HERE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  0
# 18
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  1
# 72
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  2
# 29
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  3
# 75
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  4
# 54
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  5
# 65
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  6
# 87
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  7
# 98
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# index #:  8
# 84
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# ### #2: check output matrices

# %%
waits, corrects, inputs
# Out:
# (array([2.5, 2.5]),
#  array([['18', '72', '29', '75', '54', '65', '87', '98', '84', '57', '35',
#          '38', '69', '27', '91', '93', '14', '81', '41', '30'],
#         ['25', '39', '97', '55', '84', '82', '87', '44', '92', '72', '22',
#          '59', '51', '83', '60', '49', '54', '30', '12', '64']],
#        dtype='<U2'),
#  array([['81', '41', '30', '14', '57', '89', '27', '35', '17', '19', '37',
#          '84', '27', '57', '59', '94', '84', '37', '45', '43'],
#         ['30', '12', '64', '59', '49', '25', '55', '82', '72', '84', '24',
#          '92', '88', '84', '97', '63', '24', '12', '47', '74']],
#        dtype='<U2'))

# %% [markdown]
# ### #3: Choose file name: [DITNAVN]/eksperiment[EKSPERIMENTETSNUMMER].csv

# %%
data_file_name = "serial_recall_data.csv"
data_file_name = "Ali/eksperiment1.csv"

# %% [markdown]
# ### #4: Save data in csv file CHECK DATA BEFORE RUNNING

# %%
save_data(waits = waits, corrects=corrects,userInputs = inputs,data_file_name_input = data_file_name)
